# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.17.0 in /Users/omaraguilarjr/.pyenv/versions/3.9.7/lib/python3.9/site-packages (from opencv-python) (2.0.2)
# Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl (56.7 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image in grayscale
impath = '/Users/omaraguilarjr/Downloads/0.png'
img_gray = cv2.imread(impath, cv2.IMREAD_GRAYSCALE)

# Apply histogram equalization
equalized = cv2.equalizeHist(img_gray)

# Display the result
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.title('Original')
plt.imshow(img_gray, cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Histogram Equalized')
plt.imshow(equalized, cmap='gray')
plt.axis('off')
plt.show()
