# %%
import os
import sys
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
import subprocess

# Define your parameter values
experiments = ["TRAIN_MOBILE_V1_ER1",
               "TRAIN_MOBILE_V1_ER2",
               "TRAIN_MOBILE_V1_ER3",
               "TRAIN_MOBILE_V1_ER8",
               "TRAIN_MOBILE_V1_ER9",
               "TRAIN_MOBILE_V1_ER10",
               ]
epochs = 10
model = ["densenet_og",
         "mobilenet_v1",
         "mobilenet_v2",
         "mobilenet_v3",
         "mobilenet_v4",
         "mobilenet_v5"]

exp_model_dict = {}

for exp in experiments:
    split_exp_name = exp.split("_")
    if "OG" in split_exp_name[1]:
        exp_model_dict[exp] = "densenet_og"
    elif "MOBILE" in split_exp_name[1]:
        if "V1" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v1"
        if "V2" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v2"
        if "V3" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v3"
        if "V4" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v4"
        if "V5" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v5"
    else:
        print(f"Experiment {exp} does not follow our current naming structure!")
        exit(1)

dataset_path = "../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/"

# Loop over experiments and batch sizes
for exp in experiments:
    statement = exp.split("_")[-1]
    if "BS" in statement:
        bs = int(statement[2:])
        er = 6
    elif "ER" in statement:
        er = int(statement[2:])
        bs = 8
    else:
        # defaults
        er = 6
        bs = 8
    
    # Construct the terminal command using f-string formatting.
    # cmd = f"python train.py --model {exp_model_dict[exp]} --expname {exp} --bs {bs} --epochs {epochs} --useGPU True --dataset {dataset_path} --er {er}"
    weights_list = os.listdir(os.path.join(os.getcwd(), f"../models/weights/logs/{exp}/models/"))
    # print(weights_list)
    weight = weights_list[-1]
    if weight == "dense_net_0.pkl":
        weight = weights_list[-2]
    cmd = f" python ../test.py --model {exp_model_dict[exp]} --load ../models/weights/logs/{exp}/models/{weight} --bs {bs} --dataset {dataset_path} --expname {exp[6:]} --er {er} --testsavedir /home/hice1/snachimuthu7/scratch/test"
    print("Running command:", cmd)
    # Run the command; you can set shell=True to run the command as a string.
    # result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    # # Optionally, print standard output and error:
    # print("Output:\n", result.stdout)
    # if result.stderr:
    #     print("Error:\n", result.stderr)
    os.system(cmd)
# Out:
# Running command:  python ../test.py --model mobilenet_v1 --load ../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V1_ER1 --er 1 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 1,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V1_ER1/models/TRAIN_MOBILE_V1_ER1.pkl
# 100%|██████████| 343/343 [03:05<00:00,  1.85it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:32<00:00, 503.24s/it]
# per-class mIOU:  [0.99708321 0.96190401 0.98611529 0.98472683]
# per-class precision:  [0.99750761 0.9973181  0.99903894 0.99988525]
# per-class recall:  [0.99750395 0.99731416 0.99903672 0.99988546]
# per-class f1:  [0.99750544 0.99731598 0.99903756 0.99988528]
# Total time taken: 37.376668429374696 min
# Running command:  python ../test.py --model mobilenet_v1 --load ../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V1_ER2 --er 2 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 2,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_ER2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V1_ER2/models/TRAIN_MOBILE_V1_ER2.pkl
# 100%|██████████| 343/343 [03:04<00:00,  1.86it/s]
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
