# %%
import os
import sys
from tqdm import tqdm
import numpy as np
import pandas as pd
# Out:
# /tmp/ipykernel_334372/1596881535.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import subprocess

# Define your parameter values
experiments = ["TRAIN_OG_BS4",
               "TRAIN_MOBILE_V1_BS4",
               "TRAIN_MOBILE_V2_BS4",
               "TRAIN_MOBILE_V3_BS4",
               "TRAIN_MOBILE_V4_BS4",
               "TRAIN_MOBILE_V5_BS4",
               "TRAIN_MOBILE_V1_BS8",
               "TRAIN_MOBILE_V2_BS8",
               ]
epochs = 10
model = ["densenet_og",
         "mobilenet_v1",
         "mobilenet_v2",
         "mobilenet_v3",
         "mobilenet_v4",
         "mobilenet_v5"]

exp_model_dict = {}

for exp in experiments:
    split_exp_name = exp.split("_")
    if "OG" in split_exp_name[1]:
        exp_model_dict[exp] = "densenet_og"
    elif "MOBILE" in split_exp_name[1]:
        if "V1" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v1"
        if "V2" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v2"
        if "V3" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v3"
        if "V4" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v4"
        if "V5" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v5"
    else:
        print(f"Experiment {exp} does not follow our current naming structure!")
        exit(1)

dataset_path = "../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/"

# Loop over experiments and batch sizes
for exp in experiments:
    statement = exp.split("_")[-1]
    if "BS" in statement:
        bs = int(statement[2:])
    elif "ER" in statement:
        er = int(statement[2:])
    else:
        # defaults
        er = 6
        bs = 8
    
    # Construct the terminal command using f-string formatting.
    # cmd = f"python train.py --model {exp_model_dict[exp]} --expname {exp} --bs {bs} --epochs {epochs} --useGPU True --dataset {dataset_path} --er {er}"
    weights_list = os.listdir(os.path.join(os.getcwd(), f"../models/weights/logs/{exp}/models/"))
    # print(weights_list)
    weight = weights_list[-1]
    if weight == "dense_net_0.pkl":
        weight = weights_list[-2]
        print(weight)
    cmd = f" python ../test.py --model {exp_model_dict[exp]} --load ../models/weights/logs/{exp}/models/{weight} --bs {bs} --dataset {dataset_path} --expname {exp[6:]} --er {er} --testsavedir /home/hice1/snachimuthu7/scratch/test"
    print("Running command:", cmd)
    # Run the command; you can set shell=True to run the command as a string.
    # result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    # # Optionally, print standard output and error:
    # print("Output:\n", result.stdout)
    # if result.stderr:
    #     print("Error:\n", result.stderr)
    os.system(cmd)
# Out:
# dense_net5.pkl
# Running command:  python ../test.py --model densenet_og --load ../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname OG_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG_BS4',
#  'load': '../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_OG_BS4/models/dense_net5.pkl
# 100%|██████████| 686/686 [02:13<00:00,  5.14it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:41<00:00, 505.34s/it]
# per-class mIOU:  [0.99715727 0.96239961 0.9870874  0.98731753]
# per-class precision:  [0.9975676  0.99734638 0.99910161 0.99990556]
# per-class recall:  [0.99756813 0.99734615 0.99910218 0.99990543]
# per-class f1:  [0.99756785 0.99734626 0.99910184 0.99990548]
# Total time taken: 36.665678409735364 min
# Running command:  python ../test.py --model mobilenet_v1 --load ../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V1_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V1_BS4/models/TRAIN_MOBILE_V1_BS4.pkl
# 100%|██████████| 686/686 [02:45<00:00,  4.14it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:34<00:00, 503.64s/it]
# per-class mIOU:  [0.99171768 0.89710624 0.96264515 0.94462277]
# per-class precision:  [0.99288516 0.99224039 0.9973753  0.9995663 ]
# per-class recall:  [0.99290846 0.99232444 0.99737391 0.99956878]
# per-class f1:  [0.99287632 0.99224931 0.99737458 0.99956446]
# Total time taken: 37.0902021408081 min
# Running command:  python ../test.py --model mobilenet_v2 --load ../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V2_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V2_BS4/models/TRAIN_MOBILE_V2_BS4.pkl
# 100%|██████████| 686/686 [02:44<00:00,  4.17it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:08<00:00, 497.10s/it]
# per-class mIOU:  [0.99211624 0.89719806 0.96269031 0.96545066]
# per-class precision:  [0.99323214 0.9923561  0.99742111 0.99973912]
# per-class recall:  [0.9932401  0.99241407 0.99739512 0.99973916]
# per-class f1:  [0.99323571 0.99237704 0.99740412 0.99973914]
# Total time taken: 36.612664763132734 min
# Running command:  python ../test.py --model mobilenet_v3 --load ../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V3_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V3_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v3',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V3_BS4/models/TRAIN_MOBILE_V3_BS4.pkl
# 100%|██████████| 686/686 [02:44<00:00,  4.16it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:26<00:00, 501.58s/it]
# per-class mIOU:  [0.98821321 0.85378232 0.9481945  0.96390977]
# per-class precision:  [0.9900755  0.98951507 0.99648519 0.9997261 ]
# per-class recall:  [0.98984229 0.98927809 0.99638957 0.99972668]
# per-class f1:  [0.98991354 0.98937259 0.99641767 0.99972635]
# Total time taken: 36.9308121919632 min
# Running command:  python ../test.py --model mobilenet_v4 --load ../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V4_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V4_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v4',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V4_BS4/models/TRAIN_MOBILE_V4_BS4.pkl
# 100%|██████████| 686/686 [02:45<00:00,  4.14it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:12<00:00, 498.17s/it]
# per-class mIOU:  [0.99184453 0.89119095 0.95873725 0.95795765]
# per-class precision:  [0.99299689 0.99201005 0.99707791 0.99968181]
# per-class recall:  [0.99300652 0.99201966 0.99708404 0.99968161]
# per-class f1:  [0.99300113 0.99201473 0.99708046 0.99968171]
# Total time taken: 36.73848249912262 min
# Running command:  python ../test.py --model mobilenet_v5 --load ../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl --bs 4 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V5_BS4 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 4,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V5_BS4',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v5',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V5_BS4/models/TRAIN_MOBILE_V5_BS4.pkl
# 100%|██████████| 686/686 [02:47<00:00,  4.08it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:19<00:00, 499.79s/it]
# per-class mIOU:  [0.98521606 0.79744647 0.91011081 0.9477035 ]
# per-class precision:  [0.98724258 0.98345324 0.99390489 0.99962078]
# per-class recall:  [0.98728702 0.98380582 0.99366566 0.99960884]
# per-class f1:  [0.98726065 0.98353621 0.99374099 0.99961242]
# Total time taken: 36.866026163101196 min
# Running command:  python ../test.py --model mobilenet_v1 --load ../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V1_BS8 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V1_BS8/models/TRAIN_MOBILE_V1_BS8.pkl
# 100%|██████████| 343/343 [03:06<00:00,  1.84it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:30<00:00, 502.53s/it]
# per-class mIOU:  [0.99595218 0.94987762 0.98081396 0.98464619]
# per-class precision:  [0.99653137 0.99639548 0.99867001 0.99988505]
# per-class recall:  [0.99653643 0.99641215 0.9986661  0.99988513]
# per-class f1:  [0.99653284 0.99639959 0.99866761 0.99988508]
# Total time taken: 37.33308827877045 min
# Running command:  python ../test.py --model mobilenet_v2 --load ../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V2_BS8 --testsavedir /home/hice1/snachimuthu7/scratch/test
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2_BS8',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'testsavedir': '/home/hice1/snachimuthu7/scratch/test',
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V2_BS8/models/TRAIN_MOBILE_V2_BS8.pkl
# 100%|██████████| 343/343 [02:26<00:00,  2.34it/s]
# Calculating Metrics: 100%|██████████| 4/4 [33:27<00:00, 501.90s/it]
# per-class mIOU:  [0.99603307 0.94937288 0.98321958 0.98412427]
# per-class precision:  [0.99660068 0.99636578 0.99883049 0.99988073]
# per-class recall:  [0.99660627 0.99638065 0.99883114 0.99988095]
# per-class f1:  [0.99660159 0.99637053 0.99883078 0.99988078]
# Total time taken: 36.65266977151235 min
