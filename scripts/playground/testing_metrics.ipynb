# %%
import os
import sys
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
import subprocess

# Define your parameter values
experiments = ["TRAIN_OG", 
               "TRAIN_MOBILE_V1", 
               "TRAIN_MOBILE_V2", 
               "TRAIN_MOBILE_V3", 
               "TRAIN_MOBILE_V4",
               "TRAIN_MOBILE_V5",
               "TRAIN_OG_BS4",
               "TRAIN_MOBILE_V1_BS4",
               "TRAIN_MOBILE_V2_BS4",
               "TRAIN_MOBILE_V3_BS4",
               "TRAIN_MOBILE_V4_BS4",
               "TRAIN_MOBILE_V5_BS4",
               "TRAIN_MOBILE_V1_BS8",
               "TRAIN_MOBILE_V2_BS8",
               "TRAIN_MOBILE_V1_ER1",
               "TRAIN_MOBILE_V1_ER2",
               "TRAIN_MOBILE_V1_ER3",
               "TRAIN_MOBILE_V1_ER8",
               "TRAIN_MOBILE_V1_ER9",
               "TRAIN_MOBILE_V1_ER10",
               ]
epochs = 10
model = ["densenet_og",
         "mobilenet_v1",
         "mobilenet_v2",
         "mobilenet_v3",
         "mobilenet_v4",
         "mobilenet_v5"]

exp_model_dict = {}

for exp in experiments:
    split_exp_name = exp.split("_")
    if "OG" in split_exp_name[1]:
        exp_model_dict[exp] = "densenet_og"
    elif "MOBILE" in split_exp_name[1]:
        if "V1" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v1"
        if "V2" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v2"
        if "V3" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v3"
        if "V4" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v4"
        if "V5" in split_exp_name[2]:
            exp_model_dict[exp] = "mobilenet_v5"
    else:
        print(f"Experiment {exp} does not follow our current naming structure!")
        exit(1)

dataset_path = "../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/"

# Loop over experiments and batch sizes
for exp in experiment_names:
    statement = exp.split("_")[-1]
    if "BS" in statement:
        bs = int(statement[2:])
    elif "ER" in statement:
        er = int(statement[2:])
    else:
        # defaults
        er = 6
        bs = 8
    
    # Construct the terminal command using f-string formatting.
    # cmd = f"python train.py --model {exp_model_dict[exp]} --expname {exp} --bs {bs} --epochs {epochs} --useGPU True --dataset {dataset_path} --er {er}"
    weights_list = os.listdir(os.path.join(os.getcwd(), f"../models/weights/logs/{exp}/models/"))
    # print(weights_list)
    weight = weights_list[-1]
    if weight == "dense_net_0.pkl":
        weight = weights_list[-2]
        print(weight)
    cmd = f" python ../test.py --model {exp_model_dict[exp]} --load ../models/weights/logs/{exp}/models/{weight} --bs {bs} --dataset {dataset_path} --expname {exp[6:]} --testsavedir /home/hice1/snachimuthu7/scratch/test"
    print("Running command:", cmd)
    # Run the command; you can set shell=True to run the command as a string.
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    # Optionally, print standard output and error:
    print("Output:\n", result.stdout)
    if result.stderr:
        print("Error:\n", result.stderr)
# Out:
# dense_net9.pkl
# Running command:  python ../test.py --model densenet_og --load ../models/weights/logs/TRAIN_OG/models/dense_net9.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname OG
# Output:
#  'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG',
#  'load': '../models/weights/logs/TRAIN_OG/models/dense_net9.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG',
#  'load': '../models/weights/logs/TRAIN_OG/models/dense_net9.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG',
#  'load': '../models/weights/logs/TRAIN_OG/models/dense_net9.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG',
#  'load': '../models/weights/logs/TRAIN_OG/models/dense_net9.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'OG',
#  'load': '../models/weights/logs/TRAIN_OG/models/dense_net9.pkl',
#  'lr': 0.001,
#  'model': 'densenet_og',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'O
#  13%|█▎        | 46/343 [00:25<04:07,  1.20it/s]
#  14%|█▎        | 47/343 [00:26<04:15,  1.16it/s]
#  14%|█▍        | 48/343 [00:27<03:37,  1.35it/s]
#  14%|█▍        | 49/343 [00:28<03:37,  1.35it/s]
#  15%|█▍        | 50/343 [00:29<03:59,  1.22it/s]
#  15%|█▍        | 51/343 [00:30<04:15,  1.14it/s]
#  15%|█▌        | 52/343 [00:30<03:55,  1.24it/s]
#  15%|█▌        | 52/343 [00:30<02:52,  1.69it/s]
# Traceback (most recent call last):
#   File "/home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../test.py", line 90, in <module>
#     np.save('../../../scratch/test/{}/labels/{}.npy'.format(args.expname, index[j]),predict[j].cpu().numpy())
#   File "/home/hice1/snachimuthu7/.local/lib/python3.10/site-packages/numpy/lib/npyio.py", line 544, in save
#     with file_ctx as fid:
# OSError: [Errno 122] Disk quota exceeded
#
# Running command:  python ../test.py --model mobilenet_v1 --load ../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V1
# Output:
#  'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V1',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v1',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V1/models/TRAIN_MOBILE_V1.pkl
#
# Error:
#
#   0%|          | 0/343 [00:00<?, ?it/s]
#   0%|          | 0/343 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../test.py", line 90, in <module>
#     np.save('../../../scratch/test/{}/labels/{}.npy'.format(args.expname, index[j]),predict[j].cpu().numpy())
#   File "/home/hice1/snachimuthu7/.local/lib/python3.10/site-packages/numpy/lib/npyio.py", line 544, in save
#     with file_ctx as fid:
# OSError: [Errno 122] Disk quota exceeded
#
# Running command:  python ../test.py --model mobilenet_v2 --load ../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V2
# Output:
#  'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# 'parsed input parameters:'
# {'bs': 8,
#  'dataset': '../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/openEDS '
#             'Dataset/openEDS/openEDS/',
#  'device': None,
#  'epochs': 250,
#  'er': 6,
#  'evalsplit': 'val',
#  'expname': 'MOBILE_V2',
#  'load': '../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl',
#  'lr': 0.001,
#  'model': 'mobilenet_v2',
#  'resume': False,
#  'save': '0try',
#  'savemodel': False,
#  'seed': 1111,
#  'test': False,
#  'testrun': False,
#  'useGPU': True,
#  'workers': 4}
# /home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../models/weights/logs/TRAIN_MOBILE_V2/models/TRAIN_MOBILE_V2.pkl
#
# Error:
#
#   0%|          | 0/343 [00:00<?, ?it/s]
#   0%|          | 0/343 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/hice1/snachimuthu7/BMED6780/VisualTracking/scripts/playground/../test.py", line 90, in <module>
#     np.save('../../../scratch/test/{}/labels/{}.npy'.format(args.expname, index[j]),predict[j].cpu().numpy())
#   File "/home/hice1/snachimuthu7/.local/lib/python3.10/site-packages/numpy/lib/npyio.py", line 544, in save
#     with file_ctx as fid:
# OSError: [Errno 122] Disk quota exceeded
#
# Running command:  python ../test.py --model mobilenet_v3 --load ../models/weights/logs/TRAIN_MOBILE_V3/models/TRAIN_MOBILE_V3.pkl --bs 8 --dataset ../../../../../../../storage/ice1/shared/bmed6780/mip_group_4/'openEDS Dataset'/openEDS/openEDS/ --expname MOBILE_V3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 79
#      77 print("Running command:", cmd)
#      78 # Run the command; you can set shell=True to run the command as a string.
# ---> 79 result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
#      80 # Optionally, print standard output and error:
#      81 print("Output:\n", result.stdout)
#
# File /usr/local/pace-apps/manual/packages/anaconda3/2023.03/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /usr/local/pace-apps/manual/packages/anaconda3/2023.03/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File /usr/local/pace-apps/manual/packages/anaconda3/2023.03/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File /usr/local/pace-apps/manual/packages/anaconda3/2023.03/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
